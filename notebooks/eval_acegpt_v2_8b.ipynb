# %% [markdown]
# ## Importing

# %%
from tqdm.auto import tqdm
import re, json, csv, numpy as np
from pathlib import Path
from collections import Counter

import torch, sacrebleu
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from bert_score import score as bertscore
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from tqdm.auto import tqdm
import os, re, json, random, csv
import numpy as np
from pathlib import Path

import torch, sacrebleu
from transformers import (
    AutoTokenizer, AutoModelForCausalLM, AutoModelForSequenceClassification
)
from peft import PeftModel
from bert_score import score as bertscore
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Logging to Hugging Face

# %%
login("TOKEN")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Config

# %%
MODEL_ID = "FreedomIntelligence/AceGPT-v2-8B-Chat"
OUT_DIR  = Path("eval_external_acegpt_v2_8b"); OUT_DIR.mkdir(parents=True, exist_ok=True)
PRED_DIR = OUT_DIR / "preds"; PRED_DIR.mkdir(parents=True, exist_ok=True)
TEST_PATH = Path("data_splits/test.jsonl")
GEN_KW = dict(max_new_tokens=256, do_sample=True, top_p=0.95, top_k=50, temperature=0.6)
USE_4BIT = False
SEED = 42

# %% [markdown]
# ## Loading Data

# %%
random.seed(SEED); np.random.seed(SEED); 
if torch.cuda.is_available(): torch.cuda.manual_seed_all(SEED)
device = "cuda" if torch.cuda.is_available() else "cpu"

def read_jsonl(p):
    rows=[]
    with p.open("r", encoding="utf-8") as f:
        for line in f:
            if line.strip(): rows.append(json.loads(line))
    return rows

test_rows = read_jsonl(TEST_PATH)
len(test_rows)
# Out:
# 836

# %% [markdown]
# ## Generation

# %%
def apply_chat_template_safe(tok, user_text):
    if hasattr(tok, "apply_chat_template") and tok.chat_template:
        msgs=[{"role":"user","content":user_text}]
        return tok.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)
    return f"### Instruction:\n{user_text}\n\n### Response:\n"

def load_model(model_id):
    tok = AutoTokenizer.from_pretrained(model_id, use_fast=True)
    if tok.pad_token is None: tok.pad_token = tok.eos_token
    kwargs = dict(torch_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
                  device_map="auto")
    if USE_4BIT:
        kwargs["load_in_4bit"] = True
        kwargs["quantization_config"] = BitsAndBytesConfig(
            load_in_4bit=True, bnb_4bit_compute_dtype=torch.bfloat16,
            bnb_4bit_quant_type="nf4", bnb_4bit_use_double_quant=True
        )
    model = AutoModelForCausalLM.from_pretrained(model_id, **kwargs).eval()
    return tok, model

tok, model = load_model(MODEL_ID)

preds=[]
for ex in tqdm(test_rows, desc=f"Generating: {MODEL_ID.split('/')[-1]}"):
    instr = ex.get("instruction","")
    prompt = apply_chat_template_safe(tok, instr)
    inputs = tok(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        out = model.generate(**inputs, **GEN_KW, eos_token_id=tok.eos_token_id)
    txt = tok.decode(out[0], skip_special_tokens=True)
    resp = txt.split("### Response:",1)[-1].strip() if "### Response:" in txt else txt.strip()
    preds.append({
        "prompt": instr, "gold": ex.get("response",""), "pred": resp,
        "target_dialect": (ex.get("dialect") or ex.get("meta",{}).get("dialect") or "").strip()
    })

out_path = PRED_DIR / f"{MODEL_ID.split('/')[-1]}.jsonl"
with out_path.open("w", encoding="utf-8") as f:
    for r in preds: f.write(json.dumps(r, ensure_ascii=False)+"\n")
out_path
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading shards: 100%|██████████| 4/4 [02:35<00:00, 38.96s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:10<00:00,  2.66s/it]
# Generating: AceGPT-v2-8B-Chat:   0%|          | 0/836 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   0%|          | 1/836 [00:08<1:57:32,  8.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   0%|          | 2/836 [00:14<1:34:55,  6.83s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   0%|          | 3/836 [00:16<1:08:19,  4.92s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   0%|          | 4/836 [00:23<1:19:16,  5.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|          | 5/836 [00:26<1:04:41,  4.67s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|          | 6/836 [00:27<45:55,  3.32s/it]  Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|          | 7/836 [00:30<43:46,  3.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|          | 8/836 [00:30<33:12,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|          | 9/836 [00:38<53:48,  3.90s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|          | 10/836 [00:38<39:47,  2.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|▏         | 11/836 [00:45<56:30,  4.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   1%|▏         | 12/836 [00:46<44:54,  3.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   2%|▏         | 13/836 [00:53<59:34,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   2%|▏         | 14/836 [00:57<57:08,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   2%|▏         | 15/836 [01:04<1:07:57,  4.97s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:   2%|▏         |
  3.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  91%|█████████▏| 763/836 [45:59<05:13,  4.29s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  91%|█████████▏| 764/836 [46:05<05:47,  4.83s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 765/836 [46:12<06:28,  5.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 766/836 [46:14<05:17,  4.53s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 767/836 [46:15<03:54,  3.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 768/836 [46:19<04:07,  3.65s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 769/836 [46:26<05:03,  4.53s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 770/836 [46:29<04:27,  4.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 771/836 [46:33<04:17,  3.96s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 772/836 [46:39<05:09,  4.83s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  92%|█████████▏| 773/836 [46:45<05:20,  5.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 774/836 [46:52<05:46,  5.60s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 775/836 [46:53<04:11,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 776/836 [46:54<03:20,  3.35s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 777/836 [46:55<02:32,  2.58s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 778/836 [46:56<01:59,  2.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 779/836 [46:59<02:20,  2.46s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 780/836 [47:06<03:35,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  93%|█████████▎| 781/836 [47:12<04:01,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▎| 782/836 [47:19<04:35,  5.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▎| 783/836 [47:21<03:53,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▍| 784/836 [47:28<04:25,  5.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▍| 785/836 [47:35<04:49,  5.68s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▍| 786/836 [47:42<05:04,  6.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▍| 787/836 [47:49<05:12,  6.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▍| 788/836 [47:56<05:12,  6.50s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▍| 789/836 [47:57<03:41,  4.71s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  94%|█████████▍| 790/836 [48:00<03:18,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▍| 791/836 [48:06<03:39,  4.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▍| 792/836 [48:08<02:50,  3.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▍| 793/836 [48:15<03:25,  4.77s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▍| 794/836 [48:19<03:20,  4.77s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▌| 795/836 [48:22<02:52,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▌| 796/836 [48:29<03:16,  4.92s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▌| 797/836 [48:30<02:21,  3.64s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  95%|█████████▌| 798/836 [48:31<01:57,  3.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▌| 799/836 [48:33<01:42,  2.77s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▌| 800/836 [48:40<02:22,  3.96s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▌| 801/836 [48:47<02:50,  4.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▌| 802/836 [48:48<02:08,  3.77s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▌| 803/836 [48:51<01:54,  3.46s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▌| 804/836 [48:58<02:23,  4.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▋| 805/836 [49:05<02:41,  5.21s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  96%|█████████▋| 806/836 [49:12<02:51,  5.73s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 807/836 [49:12<02:01,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 808/836 [49:17<02:03,  4.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 809/836 [49:23<02:07,  4.71s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 810/836 [49:26<01:50,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 811/836 [49:29<01:38,  3.95s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 812/836 [49:36<01:57,  4.90s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 813/836 [49:37<01:22,  3.59s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 814/836 [49:44<01:40,  4.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  97%|█████████▋| 815/836 [49:48<01:37,  4.67s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 816/836 [49:49<01:08,  3.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 817/836 [49:50<00:50,  2.67s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 818/836 [49:51<00:40,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 819/836 [49:58<01:01,  3.64s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 820/836 [49:59<00:45,  2.84s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 821/836 [50:00<00:32,  2.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 822/836 [50:06<00:50,  3.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  98%|█████████▊| 823/836 [50:13<00:59,  4.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▊| 824/836 [50:20<01:02,  5.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▊| 825/836 [50:22<00:47,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▉| 826/836 [50:29<00:49,  4.94s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▉| 827/836 [50:36<00:49,  5.51s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▉| 828/836 [50:42<00:47,  5.90s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▉| 829/836 [50:49<00:43,  6.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▉| 830/836 [50:56<00:38,  6.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat:  99%|█████████▉| 831/836 [50:57<00:23,  4.70s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat: 100%|█████████▉| 832/836 [51:04<00:21,  5.33s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat: 100%|█████████▉| 833/836 [51:05<00:12,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat: 100%|█████████▉| 834/836 [51:06<00:06,  3.21s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat: 100%|█████████▉| 835/836 [51:07<00:02,  2.54s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating: AceGPT-v2-8B-Chat: 100%|██████████| 836/836 [51:11<00:00,  3.67s/it]
# PosixPath('eval_external_acegpt_v2_8b/preds/AceGPT-v2-8B-Chat.jsonl')

# %% [markdown]
# ## Evaluation

# %%
OUT_DIR  = Path("eval_external_acegpt_v2_8b")
PRED_DIR = OUT_DIR / "preds"
OUT_DIR.mkdir(parents=True, exist_ok=True)
PRED_DIR.mkdir(parents=True, exist_ok=True)

device = "cuda" if torch.cuda.is_available() else "cpu"

# ---------- load dialect classifier ----------
# Classes: typically {MAGH, LEV, MSA, GLF, EGY}
DID_ID   = "IbrahimAmin/marbertv2-arabic-written-dialect-classifier"
did_tok  = AutoTokenizer.from_pretrained(DID_ID, use_fast=True)
did_model= AutoModelForSequenceClassification.from_pretrained(DID_ID).to(device).eval()
id2label = did_model.config.id2label
label2id = { (v if isinstance(v,str) else v.get("name","")).upper(): int(k) for k,v in id2label.items() }

def read_jsonl(p: Path):
    rows=[]
    with p.open("r", encoding="utf-8") as f:
        for line in f:
            if line.strip(): rows.append(json.loads(line))
    return rows

def camel_probs_batched(texts, bs=64):
    all_probs=[]
    for i in tqdm(range(0, len(texts), bs), desc="Dialect scoring (MARBERTv2)", leave=False):
        chunk = texts[i:i+bs]
        with torch.no_grad():
            batch = did_tok(chunk, padding=True, truncation=True, max_length=128, return_tensors="pt").to(device)
            logits = did_model(**batch).logits
            probs = torch.softmax(logits, dim=-1).cpu().numpy()
            all_probs.append(probs)
    return np.vstack(all_probs) if all_probs else np.zeros((0, len(id2label)))

def labels_from_probs(probs):
    ids = probs.argmax(axis=1)
    out=[]
    for i in ids:
        key = str(i)
        lab = id2label[key] if key in id2label else id2label[i]
        lab = lab if isinstance(lab, str) else lab.get("name","")
        out.append(lab.upper().strip())
    return out

def is_saudi(lbl: str) -> bool:
    return "GLF" in lbl

MSA_IDX = None
for raw, idx in label2id.items():
    if "MSA" in raw:
        MSA_IDX = idx
        break

# ---------- helpers ----------
def tag_echo_rate(texts):
    patt = re.compile(r'<\s*DIALECT\s*=\s*[^>]+>', re.IGNORECASE)
    return 100.0 * float(np.mean([bool(patt.search(t)) for t in texts]))

def diversity_metrics(preds):
    def ngrams(tokens, n): return list(zip(*[tokens[i:] for i in range(n)]))
    total_bi=total_tri=0; uniq_bi=set(); uniq_tri=set()
    for p in preds:
        t=p.split()
        b=ngrams(t,2); g=ngrams(t,3)
        total_bi += max(1,len(b)); total_tri += max(1,len(g))
        uniq_bi.update(b); uniq_tri.update(g)
    d2 = len(uniq_bi)/total_bi if total_bi else 0.0
    d3 = len(uniq_tri)/total_tri if total_tri else 0.0
    if len(preds) < 2:
        sbleu = 0.0
    else:
        scores=[]
        for i in range(len(preds)):
            hyp=[preds[i]]
            refs=[[p for j,p in enumerate(preds) if j!=i]]
            scores.append(sacrebleu.corpus_bleu(hyp, refs).score)
        sbleu = float(np.mean(scores))
    return d2, d3, sbleu

_ar_punct = r"[^\w\s\u0600-\u06FF]"
_ar_tatweel = "\u0640"
_ar_diacritics = re.compile(r"[\u0610-\u061A\u064B-\u065F\u06D6-\u06ED]")

def normalize_ar(text: str) -> str:
    t = text
    t = t.replace(_ar_tatweel, "")                 
    t = _ar_diacritics.sub("", t)                  
    t = re.sub(r"\s+", " ", t)                    
    t = re.sub(_ar_punct, " ", t)                  
    return t.strip()

def near_duplicate_rate(preds, thr=0.90):
    if len(preds) < 2:
        return 0.0
    norm = [normalize_ar(p) for p in preds]
    vec = TfidfVectorizer(analyzer="word", ngram_range=(1,3), min_df=1)
    X = vec.fit_transform(norm)
    sims = cosine_similarity(X)
    n = X.shape[0]; cnt = 0; denom = n*(n-1)/2
    for i in range(n):
        for j in range(i+1, n):
            if sims[i, j] >= thr:
                cnt += 1
    return 100.0 * cnt / max(1, denom)

try:
    pred_files
except NameError:
    pred_files = sorted(PRED_DIR.glob("*.jsonl"))

if not pred_files:
    raise FileNotFoundError(f"No prediction files found in {PRED_DIR}. Make sure generation saved *.jsonl there.")

# %% [markdown]
# ## Summarize

# %%
summary=[]
for pf in pred_files:
    name  = Path(pf).stem
    rows  = read_jsonl(pf)
    preds = [r["pred"] for r in rows]
    golds = [r["gold"] for r in rows]

    probs = camel_probs_batched(preds, bs=64)
    labs  = labels_from_probs(probs)
    conf  = probs.max(axis=1)

    print(f"{name} label counts:", Counter(labs)) 

    msa_leak = float(np.mean(probs[:, MSA_IDX]))*100.0 if (MSA_IDX is not None and probs.shape[1] > MSA_IDX) else 0.0
    saudi_rate = 100.0*float(np.mean([is_saudi(x) for x in labs]))
    low_conf   = 100.0*float(np.mean(conf < 0.55))
    echo       = tag_echo_rate(preds)

    chrf = sacrebleu.corpus_chrf(preds, [golds]).score
    P,R,F = bertscore(preds, golds, lang="ar", rescale_with_baseline=True, device=device)
    bert_f1 = float(F.mean().item())

    d2, d3, sbleu = diversity_metrics(preds)
    near_dup = near_duplicate_rate(preds, thr=0.90)

    with (OUT_DIR / f"{name}_report.json").open("w", encoding="utf-8") as f:
        json.dump({
            "model": name, "n": len(rows),
            "saudi_rate_pct": saudi_rate,
            "msa_leak_pct": msa_leak,
            "low_conf_pct": low_conf,
            "tag_echo_pct": echo,
            "chrF++": chrf,
            "BERTScore_F1": bert_f1,
            "distinct2": d2, "distinct3": d3, "selfBLEU": sbleu,
            "near_duplicate_pct": near_dup
        }, f, ensure_ascii=False, indent=2)

    summary.append([
        name, round(saudi_rate,2), round(msa_leak,2), round(low_conf,2),
        round(echo,2), round(chrf,2), round(bert_f1,4),
        round(d2,4), round(d3,4), round(sbleu,2), round(near_dup,2)
    ])

csv_path = OUT_DIR / "summary_saudi_only.csv"
with csv_path.open("w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow([
        "Model","Saudi% (GLF) ↑","MSA leak% ↓","Low-conf% ↓",
        "Tag-echo% ↓","chrF++ ↑","BERTScore F1 ↑",
        "distinct-2 ↑","distinct-3 ↑","Self-BLEU ↓","Near-dup% ↓"
    ])
    for row in summary: w.writerow(row)

print("\n== Summary ==")
for row in summary: print(row)
print(f"\nSaved: {csv_path}")
# Out:
# AceGPT-v2-8B-Chat label counts: Counter({'GLF': 568, 'MSA': 183, 'LEV': 79, 'MAGHREB': 3, 'EGY': 3})
# Warning: Baseline not Found for bert-base-multilingual-cased on ar at /workspace/.venv/lib/python3.11/site-packages/bert_score/rescale_baseline/ar/bert-base-multilingual-cased.tsv
# == Summary ==
# ['AceGPT-v2-8B-Chat', 67.94, 22.02, 6.94, 83.97, 21.59, 0.6688, 0.7902, 0.9409, 0.31, 0.0]
#
# Saved: eval_external_acegpt_v2_8b/summary_saudi_only.csv
